# %%
# Execute if necessary
# %%capture
# !pip install numpy seaborn matplotlib pandas openml

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from typing import Dict, Tuple, Union, List
import openml
import sklearn

# %% [markdown]
# # Práctica 4: Overfitting

# %% [markdown]
# __Instrucciones__: A continuación hay una lista de funciones que debe implementar o tareas que debe desarrollar. La descripción de cada una de ellas se encuentra en la definición de cada una de las funciones. Cada función está marcada por &#x1F625;,  &#x1F643; o &#x1F921;. Las marcas indican:
#
# - &#x1F625;: Indican una entrega que debe ser hecha dentro de la misma sesión de la asignación.
# - &#x1F643;: Indican una entrega que puede ser hecha hasta la siguiente sesión.
# - &#x1F921;: Debe mostrar un avance en la misma sesión, pero la entrega puede ser hecha en la siguiente.
#
# Aquellas entregas parciales que no sean hechas el día de la asignación ya no serán válidas para las entregas totales, sin embargo, las entregas totales seguirán siendo válidas.

# %% [markdown]
# En esta sección se incluye un dataset real. El dataset importado se llama LDPA y puede leer su descripción en la siguiente liga
#
# https://www.openml.org/d/1483

# %%
# Descarga la metadata del dataset
dataset_info = openml.datasets.get_dataset(1483, download_data=False)

# Obtiene el nombre de la columna a predecir
target = dataset_info.default_target_attribute

(
    features, # Dataframe con las características que se pueden utilizar para predecir
    outputs, # Columna a predecir
    categorical_mask, # Máscara que indica que columnas de todas las características son categoricas
    columns # Lista con el nombre de las características
)= dataset_info.get_data(
    dataset_format="dataframe", target=target
)

categorical_mask = np.array(categorical_mask)
columns = np.array(columns)

# %%
print(f"La columna a predecir se llama '{target}'")
print(f"Todas las características son {str(columns)}")
print(f"Las características categóricas son {str(columns[categorical_mask])}")
print(f"Las características numéricas son {str(columns[~categorical_mask])}")
# Out:
# La columna a predecir se llama 'Class'
# Todas las características son ['V1' 'V2' 'V3' 'V4' 'V5' 'V6' 'V7']
# Las características categóricas son ['V1' 'V2']
# Las características numéricas son ['V3' 'V4' 'V5' 'V6' 'V7']

# %%
# Impresión de las características
features
# Out:
#        V1 V2        V3        V4        V5        V6        V7
# 0       1  1  105794.0  105777.0  148933.0  108479.0  109365.0
# 1       1  4  105795.0  105778.0  155325.0   96952.0  161363.0
# 2       1  3  105796.0  105779.0  156652.0  101610.0  148870.0
# 3       1  1  105797.0  105780.0  149736.0  107135.0  102479.0
# 4       1  2  105798.0  105781.0  155978.0  125455.0  106203.0
# ...    .. ..       ...       ...       ...       ...       ...
# 164855  5  2   43687.0   43679.0  106611.0  123166.0   12432.0
# 164856  5  1   43688.0   43680.0  120821.0  119848.0   87463.0
# 164857  5  4   43689.0   43681.0  104999.0  110823.0  161536.0
# 164858  5  2   43690.0   43682.0  102191.0  112520.0   10811.0
# 164859  5  1   43691.0   43683.0  106656.0  113422.0   80572.0
#
# [164860 rows x 7 columns]

# %%
outputs
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 164855    3
# 164856    3
# 164857    3
# 164858    3
# 164859    3
# Name: Class, Length: 164860, dtype: category
# Categories (11, object): ['1' < '2' < '3' < '4' ... '8' < '9' < '10' < '11']

# %% [markdown]
# A continuación se realiza la partición de __train__ y __test__. __No debe utilizar la partición de test por ningún motivo__.

# %%
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
    features, 
    outputs, 
    test_size=0.5, 
    random_state=11
)

# %% [markdown]
# ## Asignación 1 &#x1F921;
#
# Utilizando las técnicas vistas en clase, realicé su mejor esfuerzo para obtener el mejor modelo lineal posible utilizando __únicamente el conjunto de entrenamiento__ (X_train y y_train). Puede utilizar bibliotecas, pero únicamente las técnicas vistas en clase y debe ir generando métricas o visualizaciones que respalden su toma de decisiones. Debe tener e imprimir una estimación de $E_{out}$ utilizando su conjunto de entrenamiento. La métrica utilizada será la entropía cruzada.

# %% [markdown]
# ## EDA

# %%
def check_nans(df):
    for c in list(df.columns.values):
        print(c + ' NaNs -> ' + str(df[c].isnull().sum()))

# %%
def plot_hist(column):
    skewness = calc_skewness(column)
    __fig__, __axs__ = plt.subplots(ncols=1, figsize=(15, 5))
    __fig__.subplots_adjust(hspace=0.1, wspace=0.3)
    
    __axs__.set(title="{} (mean = {}, std = {}, skewness = {})".format(column.name, round(column.mean(), 2), round(column.std(), 2), round(skewness, 2)))
    _ = sns.histplot(x=column, ax=__axs__)
    _.axvline(x=column.mean(),
                color='blue',
                ls='--', 
                lw=2.5)

# %%
def calc_skewness(x):
    return (((x - x.mean()) / (x.var() ** (1/2))) ** 3).mean()

# %%
check_nans(X_train)
# Out:
# V1 NaNs -> 0
# V2 NaNs -> 0
# V3 NaNs -> 0
# V4 NaNs -> 0
# V5 NaNs -> 0
# V6 NaNs -> 0
# V7 NaNs -> 0

# %% [markdown]
# ## Histogramas

# %%
column = X_train.V1
__fig__, __axs__ = plt.subplots(ncols=1, figsize=(15, 5))
__fig__.subplots_adjust(hspace=0.1, wspace=0.3)
    
__axs__.set(title="{}".format(column.name))
_ = sns.histplot(x=column, ax=__axs__)

# %%
column = X_train.V2
__fig__, __axs__ = plt.subplots(ncols=1, figsize=(15, 5))
__fig__.subplots_adjust(hspace=0.1, wspace=0.3)
    
__axs__.set(title="{}".format(column.name))
_ = sns.histplot(x=column, ax=__axs__)

# %%
plot_hist(X_train.V3)

# %%
plot_hist(X_train.V4)

# %%
plot_hist(X_train.V5)

# %%
plot_hist(X_train.V6)

# %%
plot_hist(X_train.V7)

# %% [markdown]
# Podemos visualizar que las distribuciones de nuestras variables numéricas son prácticamente uniformes.

# %% [markdown]
# ### Proporción de clases (desbalanceada)

# %%
from collections import Counter

# %%
count_y_train = dict(sorted(dict(Counter(y_train)).items(), key=lambda x:x[1], reverse=True))
count_y_train
# Out:
# {'4': 27168,
#  '3': 16359,
#  '7': 13621,
#  '10': 9275,
#  '9': 5884,
#  '5': 3045,
#  '6': 2665,
#  '1': 1497,
#  '2': 1360,
#  '8': 852,
#  '11': 704}

# %%
counts_ls = list(count_y_train.values())

# %%
counts_ls_prob = [elem / sum(counts_ls) for elem in counts_ls]

# %%
class_ls = list(count_y_train.keys())

# %%
fig = plt.figure(figsize = (10, 5))
plt.bar(class_ls, counts_ls_prob, color ='maroon',
        width = 0.4)
plt.show()

# %% [markdown]
# Asimismo podemos observar que las clases a predecir están muy desbalanceadas, lo que probablemente nos generará que el clasificador solo prediga las clases más repetidas, como la 4, 3 y 7.

# %%
all_train = pd.concat((X_train, pd.to_numeric(y_train)), axis = 1)
all_train
# Out:
#        V1 V2        V3        V4        V5        V6        V7  Class
# 82677   3  3  158321.0  158297.0   72476.0  106489.0  146328.0      3
# 2843    1  1  108637.0  108619.0  135179.0   75851.0   79479.0     10
# 50670   2  2   98841.0   98825.0   76316.0  137080.0  101775.0      4
# 128441  5  4    7274.0    7273.0   97161.0  128160.0  137973.0      2
# 10592   1  2  116386.0  116368.0   70382.0  140689.0  119402.0      4
# ...    .. ..       ...       ...       ...       ...       ...    ...
# 102327  4  2   56803.0   56792.0  146134.0  114564.0   47575.0      3
# 97617   4  2   52093.0   52085.0   54989.0   81198.0   26584.0     11
# 21584   1  1  127378.0  127358.0   44795.0  105412.0   49255.0      3
# 36543   2  2   84714.0   84700.0   59207.0   33106.0  114460.0      3
# 141209  5  1   20042.0   20038.0   51811.0  160448.0   82863.0      4
#
# [82430 rows x 8 columns]

# %%
corr = all_train.corr()
corr.style.background_gradient(cmap = 'YlOrRd')
# Out:
# <style type="text/css">
# #T_5218d_row0_col0, #T_5218d_row0_col1, #T_5218d_row1_col0, #T_5218d_row1_col1, #T_5218d_row2_col2, #T_5218d_row3_col3, #T_5218d_row4_col4, #T_5218d_row5_col5 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_5218d_row0_col2, #T_5218d_row1_col2 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_5218d_row0_col3, #T_5218d_row1_col3 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_5218d_row0_col4, #T_5218d_row1_col4, #T_5218d_row2_col4 {
#   background-color: #fffdc6;
#   color: #000000;
# }
# #T_5218d_row0_col5, #T_5218d_row1_col5, #T_5218d_row4_col0, #T_5218d_row4_col1 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_5218d_row2_col0, #T_5218d_row2_col1, #T_5218d_row2_col3, #T_5218d_row3_col2, #T_5218d_row3_col4, #T_5218d_row3_col5, #T_5218d_row5_col4 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_5218d_row2_col5 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_5218d_row3_col0, #T_5218d_row3_col1 {
#   background-color: #fff7b7;
#   color: #000000;
# }
# #T_5218d_row4_col2 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_5218d_row4_col3 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_5218d_row4_col5 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_5218d_row5_col0, #T_5218d_row5_col1 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_5218d_row5_col2 {
#   background-color: #fec35e;
#   color: #000000;
# }
# #T_5218d_row5_col3 {
#   background-color: #fee288;
#   color: #000000;
# }
# </style>
# <table id="T_5218d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5218d_level0_col0" class="col_heading level0 col0" >V3</th>
#       <th id="T_5218d_level0_col1" class="col_heading level0 col1" >V4</th>
#       <th id="T_5218d_level0_col2" class="col_heading level0 col2" >V5</th>
#       <th id="T_5218d_level0_col3" class="col_heading level0 col3" >V6</th>
#       <th id="T_5218d_level0_col4" class="col_heading level0 col4" >V7</th>
#       <th id="T_5218d_level0_col5" class="col_heading level0 col5" >Class</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5218d_level0_row0" class="row_heading level0 row0" >V3</th>
#       <td id="T_5218d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5218d_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_5218d_row0_col2" class="data row0 col2" >-0.090484</td>
#       <td id="T_5218d_row0_col3" class="data row0 col3" >-0.022801</td>
#       <td id="T_5218d_row0_col4" class="data row0 col4" >0.026448</td>
#       <td id="T_5218d_row0_col5" class="data row0 col5" >0.022978</td>
#     </tr>
#     <tr>
#       <th id="T_5218d_level0_row1" class="row_heading level0 row1" >V4</th>
#       <td id="T_5218d_row1_col0" class="data row1 col0" >1.000000</td>
#       <td id="T_5218d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5218d_row1_col2" class="data row1 col2" >-0.090482</td>
#       <td id="T_5218d_row1_col3" class="data row1 col3" >-0.022802</td>
#       <td id="T_5218d_row1_col4" class="data row1 col4" >0.026448</td>
#       <td id="T_5218d_row1_col5" class="data row1 col5" >0.022979</td>
#     </tr>
#     <tr>
#       <th id="T_5218d_level0_row2" class="row_heading level0 row2" >V5</th>
#       <td id="T_5218d_row2_col0" class="data row2 col0" >-0.090484</td>
#       <td id="T_5218d_row2_col1" class="data row2 col1" >-0.090482</td>
#       <td id="T_5218d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5218d_row2_col3" class="data row2 col3" >-0.366917</td>
#       <td id="T_5218d_row2_col4" class="data row2 col4" >0.026174</td>
#       <td id="T_5218d_row2_col5" class="data row2 col5" >0.072940</td>
#     </tr>
#     <tr>
#       <th id="T_5218d_level0_row3" class="row_heading level0 row3" >V6</th>
#       <td id="T_5218d_row3_col0" class="data row3 col0" >-0.022801</td>
#       <td id="T_5218d_row3_col1" class="data row3 col1" >-0.022802</td>
#       <td id="T_5218d_row3_col2" class="data row3 col2" >-0.366917</td>
#       <td id="T_5218d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_5218d_row3_col4" class="data row3 col4" >0.013580</td>
#       <td id="T_5218d_row3_col5" class="data row3 col5" >-0.095771</td>
#     </tr>
#     <tr>
#       <th id="T_5218d_level0_row4" class="row_heading level0 row4" >V7</th>
#       <td id="T_5218d_row4_col0" class="data row4 col0" >0.026448</td>
#       <td id="T_5218d_row4_col1" class="data row4 col1" >0.026448</td>
#       <td id="T_5218d_row4_col2" class="data row4 col2" >0.026174</td>
#       <td id="T_5218d_row4_col3" class="data row4 col3" >0.013580</td>
#       <td id="T_5218d_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_5218d_row4_col5" class="data row4 col5" >0.010421</td>
#     </tr>
#     <tr>
#       <th id="T_5218d_level0_row5" class="row_heading level0 row5" >Class</th>
#       <td id="T_5218d_row5_col0" class="data row5 col0" >0.022978</td>
#       <td id="T_5218d_row5_col1" class="data row5 col1" >0.022979</td>
#       <td id="T_5218d_row5_col2" class="data row5 col2" >0.072940</td>
#       <td id="T_5218d_row5_col3" class="data row5 col3" >-0.095771</td>
#       <td id="T_5218d_row5_col4" class="data row5 col4" >0.010421</td>
#       <td id="T_5218d_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#sns.pairplot(all_train, hue = 'Class', diag_kind='kde')

# %% [markdown]
# ### Kmeans para generar columna adicional

# %% [markdown]
# Por mera experimentación, realizaremos un clustering para poder generar una columna adicional donde se incluye la etiqueta del cluster a la que un determinado registro pertenece, esto para intentar ayudar a que el modelo pueda clasificar de una mejor forma.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

# %%
distortions = []
K = range(1,10)
for k in K:
    kmeanModel = KMeans(n_clusters=k)
    kmeanModel.fit(X_train)
    distortions.append(kmeanModel.inertia_)

# %%
plt.figure(figsize=(16,8))
plt.plot(K, distortions, 'bx-')
plt.xlabel('k')
plt.ylabel('Distortion')
plt.title('The Elbow Method showing the optimal k')
plt.show()

# %% [markdown]
# Con el gráfico del codo, observamos que la cantidad de cluster sugeridos es de 2. Por lo que procedemos a implementar un KMeans con el conjunto de entrenamiento.

# %%
k_opt = 2

# %%
km = KMeans(
    n_clusters=k_opt, init='random',
    n_init=10, max_iter=300, 
    tol=1e-04, random_state=0
)

# %% [markdown]
# Una vez entrenado el modelo de agrupamiento, predecimos y añadimos etiqueta del cluster a los datos de entrenamiento.

# %%
y_km_train = km.fit_predict(X_train)

# %%
indexes_train = X_train.index.values

# %%
y_km_train_df = pd.DataFrame(y_km_train, columns = ['cluster']).set_index(indexes_train, drop=True, append=False, inplace=False, verify_integrity=False)

# %%
#X_train = pd.concat((X_train, y_km_train_df), axis = 1)
#X_train

# %% [markdown]
# Análogamente, hacemos lo mismo en los datos de prueba. Cabe mencionar que no estamos alterando el contenido original de los datos de prueba, ya que solamente le estamos agregando una columna que igual colocamos en el entrenamiento.

# %%
y_km_test = km.fit_predict(X_test)

# %%
indexes_test = X_test.index.values

# %%
y_km_test_df = pd.DataFrame(y_km_test, columns = ['cluster']).set_index(indexes_test, drop=True, append=False, inplace=False, verify_integrity=False)

# %%
#X_test = pd.concat((X_test, y_km_test_df), axis = 1)
#X_test

# %% [markdown]
# ## Preprocesamiento

# %%
import copy

# %%
X_train_pp = copy.deepcopy(X_train)
X_train_pp
# Out:
#        V1 V2        V3        V4        V5        V6        V7
# 82677   3  3  158321.0  158297.0   72476.0  106489.0  146328.0
# 2843    1  1  108637.0  108619.0  135179.0   75851.0   79479.0
# 50670   2  2   98841.0   98825.0   76316.0  137080.0  101775.0
# 128441  5  4    7274.0    7273.0   97161.0  128160.0  137973.0
# 10592   1  2  116386.0  116368.0   70382.0  140689.0  119402.0
# ...    .. ..       ...       ...       ...       ...       ...
# 102327  4  2   56803.0   56792.0  146134.0  114564.0   47575.0
# 97617   4  2   52093.0   52085.0   54989.0   81198.0   26584.0
# 21584   1  1  127378.0  127358.0   44795.0  105412.0   49255.0
# 36543   2  2   84714.0   84700.0   59207.0   33106.0  114460.0
# 141209  5  1   20042.0   20038.0   51811.0  160448.0   82863.0
#
# [82430 rows x 7 columns]

# %%
X_test_pp = copy.deepcopy(X_test)
X_test_pp
# Out:
#        V1 V2        V3        V4        V5        V6        V7
# 9783    1  4  115577.0  115559.0   90402.0   18088.0  121817.0
# 85013   3  4  160657.0  160632.0    5651.0  148068.0   64938.0
# 70883   3  1  146527.0  146506.0   27276.0  100859.0  115620.0
# 64466   3  2  140110.0  140090.0   17717.0   63955.0   11320.0
# 82448   3  4  158092.0  158068.0     399.0  161841.0  163997.0
# ...    .. ..       ...       ...       ...       ...       ...
# 102897  4  1   57373.0   57362.0   64919.0   55294.0   68753.0
# 40732   2  2   88903.0   88889.0   34335.0   31755.0   72117.0
# 114945  4  3   69421.0   69407.0   23650.0   37747.0  133916.0
# 19389   1  2  125183.0  125165.0  123080.0   18023.0   89884.0
# 155502  5  4   34334.0   34328.0  122908.0  162355.0  139577.0
#
# [82430 rows x 7 columns]

# %% [markdown]
# ### OneHotEncoding

# %% [markdown]
# Codificamos las columnas V1, V2 y cluster ya que son de caracter categórico, tanto en el conjunto de entrenamiento como de prueba.

# %%
def ohe(df, columns):
    for col in columns:
        #print(col)
        col_encoded = pd.get_dummies(pd.Series(df[col]))
        #print(col_encoded.head(3))
        df[['{}_'.format(col) + str(c) for c in list(col_encoded.columns.values)]] = col_encoded
        df = df.drop(columns = col)
        
    return df

# %%
#cols_to_encode = ['V1', 'V2', 'cluster']
cols_to_encode = ['V1', 'V2']

# %%
X_train_ohe = ohe(copy.deepcopy(X_train_pp), cols_to_encode)

# %%
X_train_ohe
# Out:
#               V3        V4        V5        V6        V7  V1_1  V1_2  V1_3  \
# 82677   158321.0  158297.0   72476.0  106489.0  146328.0     0     0     1
# 2843    108637.0  108619.0  135179.0   75851.0   79479.0     1     0     0
# 50670    98841.0   98825.0   76316.0  137080.0  101775.0     0     1     0
# 128441    7274.0    7273.0   97161.0  128160.0  137973.0     0     0     0
# 10592   116386.0  116368.0   70382.0  140689.0  119402.0     1     0     0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 102327   56803.0   56792.0  146134.0  114564.0   47575.0     0     0     0
# 97617    52093.0   52085.0   54989.0   81198.0   26584.0     0     0     0
# 21584   127378.0  127358.0   44795.0  105412.0   49255.0     1     0     0
# 36543    84714.0   84700.0   59207.0   33106.0  114460.0     0     1     0
# 141209   20042.0   20038.0   51811.0  160448.0   82863.0     0     0     0
#
#         V1_4  V1_5  V2_1  V2_2  V2_3  V2_4
# 82677      0     0     0     0     1     0
# 2843       0     0     1     0     0     0
# 50670      0     0     0     1     0     0
# 128441     0     1     0     0     0     1
# 10592      0     0     0     1     0     0
# ...      ...   ...   ...   ...   ...   ...
# 102327     1     0     0     1     0     0
# 97617      1     0     0     1     0     0
# 21584      0     0     1     0     0     0
# 36543      0     0     0     1     0     0
# 141209     0     1     1     0     0     0
#
# [82430 rows x 14 columns]

# %%
X_test_ohe = ohe(copy.deepcopy(X_test_pp), cols_to_encode)

# %%
X_test_ohe
# Out:
#               V3        V4        V5        V6        V7  V1_1  V1_2  V1_3  \
# 9783    115577.0  115559.0   90402.0   18088.0  121817.0     1     0     0
# 85013   160657.0  160632.0    5651.0  148068.0   64938.0     0     0     1
# 70883   146527.0  146506.0   27276.0  100859.0  115620.0     0     0     1
# 64466   140110.0  140090.0   17717.0   63955.0   11320.0     0     0     1
# 82448   158092.0  158068.0     399.0  161841.0  163997.0     0     0     1
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 102897   57373.0   57362.0   64919.0   55294.0   68753.0     0     0     0
# 40732    88903.0   88889.0   34335.0   31755.0   72117.0     0     1     0
# 114945   69421.0   69407.0   23650.0   37747.0  133916.0     0     0     0
# 19389   125183.0  125165.0  123080.0   18023.0   89884.0     1     0     0
# 155502   34334.0   34328.0  122908.0  162355.0  139577.0     0     0     0
#
#         V1_4  V1_5  V2_1  V2_2  V2_3  V2_4
# 9783       0     0     0     0     0     1
# 85013      0     0     0     0     0     1
# 70883      0     0     1     0     0     0
# 64466      0     0     0     1     0     0
# 82448      0     0     0     0     0     1
# ...      ...   ...   ...   ...   ...   ...
# 102897     1     0     1     0     0     0
# 40732      0     0     0     1     0     0
# 114945     1     0     0     0     1     0
# 19389      0     0     0     1     0     0
# 155502     0     1     0     0     0     1
#
# [82430 rows x 14 columns]

# %%
all_train_aux = pd.concat((X_train_ohe, pd.to_numeric(y_train)), axis = 1)
all_train_aux
# Out:
#               V3        V4        V5        V6        V7  V1_1  V1_2  V1_3  \
# 82677   158321.0  158297.0   72476.0  106489.0  146328.0     0     0     1
# 2843    108637.0  108619.0  135179.0   75851.0   79479.0     1     0     0
# 50670    98841.0   98825.0   76316.0  137080.0  101775.0     0     1     0
# 128441    7274.0    7273.0   97161.0  128160.0  137973.0     0     0     0
# 10592   116386.0  116368.0   70382.0  140689.0  119402.0     1     0     0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 102327   56803.0   56792.0  146134.0  114564.0   47575.0     0     0     0
# 97617    52093.0   52085.0   54989.0   81198.0   26584.0     0     0     0
# 21584   127378.0  127358.0   44795.0  105412.0   49255.0     1     0     0
# 36543    84714.0   84700.0   59207.0   33106.0  114460.0     0     1     0
# 141209   20042.0   20038.0   51811.0  160448.0   82863.0     0     0     0
#
#         V1_4  V1_5  V2_1  V2_2  V2_3  V2_4  Class
# 82677      0     0     0     0     1     0      3
# 2843       0     0     1     0     0     0     10
# 50670      0     0     0     1     0     0      4
# 128441     0     1     0     0     0     1      2
# 10592      0     0     0     1     0     0      4
# ...      ...   ...   ...   ...   ...   ...    ...
# 102327     1     0     0     1     0     0      3
# 97617      1     0     0     1     0     0     11
# 21584      0     0     1     0     0     0      3
# 36543      0     0     0     1     0     0      3
# 141209     0     1     1     0     0     0      4
#
# [82430 rows x 15 columns]

# %%
corr = all_train_aux.corr()
corr.style.background_gradient(cmap = 'YlOrRd')
# Out:
# <style type="text/css">
# #T_04af4_row0_col0, #T_04af4_row0_col1, #T_04af4_row1_col0, #T_04af4_row1_col1, #T_04af4_row2_col2, #T_04af4_row3_col3, #T_04af4_row4_col4, #T_04af4_row5_col5, #T_04af4_row6_col6, #T_04af4_row7_col7, #T_04af4_row8_col8, #T_04af4_row9_col9, #T_04af4_row10_col10, #T_04af4_row11_col11, #T_04af4_row12_col12, #T_04af4_row13_col13, #T_04af4_row14_col14 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_04af4_row0_col2, #T_04af4_row1_col2, #T_04af4_row2_col6, #T_04af4_row3_col6, #T_04af4_row9_col13, #T_04af4_row13_col6, #T_04af4_row14_col8 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_04af4_row0_col3, #T_04af4_row1_col3, #T_04af4_row12_col3, #T_04af4_row13_col7 {
#   background-color: #fed976;
#   color: #000000;
# }
# #T_04af4_row0_col4, #T_04af4_row0_col10, #T_04af4_row1_col4, #T_04af4_row1_col10, #T_04af4_row2_col4, #T_04af4_row3_col7, #T_04af4_row4_col6, #T_04af4_row6_col4, #T_04af4_row10_col6, #T_04af4_row12_col8, #T_04af4_row14_col13 {
#   background-color: #fedb7a;
#   color: #000000;
# }
# #T_04af4_row0_col5, #T_04af4_row1_col5 {
#   background-color: #fd913e;
#   color: #000000;
# }
# #T_04af4_row0_col6, #T_04af4_row0_col13, #T_04af4_row1_col6, #T_04af4_row1_col13, #T_04af4_row4_col2, #T_04af4_row8_col3, #T_04af4_row9_col3, #T_04af4_row9_col10 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_04af4_row0_col7, #T_04af4_row1_col7 {
#   background-color: #e2191c;
#   color: #f1f1f1;
# }
# #T_04af4_row0_col8, #T_04af4_row1_col8, #T_04af4_row6_col5, #T_04af4_row7_col8 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_04af4_row0_col9, #T_04af4_row1_col9, #T_04af4_row2_col3, #T_04af4_row3_col2, #T_04af4_row3_col14, #T_04af4_row9_col0, #T_04af4_row9_col1, #T_04af4_row9_col5, #T_04af4_row9_col6, #T_04af4_row9_col7, #T_04af4_row9_col8, #T_04af4_row10_col11, #T_04af4_row10_col12, #T_04af4_row10_col13, #T_04af4_row11_col4, #T_04af4_row11_col10, #T_04af4_row11_col12, #T_04af4_row11_col13, #T_04af4_row12_col10, #T_04af4_row12_col11, #T_04af4_row12_col13 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_04af4_row0_col11, #T_04af4_row1_col11, #T_04af4_row2_col11, #T_04af4_row2_col12, #T_04af4_row6_col11, #T_04af4_row7_col13, #T_04af4_row13_col5, #T_04af4_row14_col11 {
#   background-color: #fed572;
#   color: #000000;
# }
# #T_04af4_row0_col12, #T_04af4_row1_col12, #T_04af4_row5_col10, #T_04af4_row14_col7 {
#   background-color: #fedb7b;
#   color: #000000;
# }
# #T_04af4_row0_col14, #T_04af4_row1_col14 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_04af4_row2_col0, #T_04af4_row2_col1 {
#   background-color: #feb04b;
#   color: #000000;
# }
# #T_04af4_row2_col5, #T_04af4_row4_col7, #T_04af4_row6_col13, #T_04af4_row10_col7, #T_04af4_row12_col6, #T_04af4_row13_col2, #T_04af4_row13_col8, #T_04af4_row14_col5 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_04af4_row2_col7, #T_04af4_row2_col8, #T_04af4_row2_col13 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_04af4_row2_col9, #T_04af4_row4_col13 {
#   background-color: #fd903d;
#   color: #000000;
# }
# #T_04af4_row2_col10 {
#   background-color: #fec965;
#   color: #000000;
# }
# #T_04af4_row2_col14 {
#   background-color: #ffe997;
#   color: #000000;
# }
# #T_04af4_row3_col0, #T_04af4_row3_col1 {
#   background-color: #fea546;
#   color: #000000;
# }
# #T_04af4_row3_col4, #T_04af4_row7_col2, #T_04af4_row8_col2, #T_04af4_row8_col13, #T_04af4_row11_col8, #T_04af4_row14_col6 {
#   background-color: #fedc7c;
#   color: #000000;
# }
# #T_04af4_row3_col5 {
#   background-color: #ffe691;
#   color: #000000;
# }
# #T_04af4_row3_col8, #T_04af4_row3_col11, #T_04af4_row6_col2, #T_04af4_row6_col3, #T_04af4_row8_col10 {
#   background-color: #fed977;
#   color: #000000;
# }
# #T_04af4_row3_col9, #T_04af4_row4_col0, #T_04af4_row4_col1, #T_04af4_row14_col0, #T_04af4_row14_col1 {
#   background-color: #fd9d43;
#   color: #000000;
# }
# #T_04af4_row3_col10, #T_04af4_row8_col0, #T_04af4_row8_col1 {
#   background-color: #feca66;
#   color: #000000;
# }
# #T_04af4_row3_col12, #T_04af4_row11_col7 {
#   background-color: #feda78;
#   color: #000000;
# }
# #T_04af4_row3_col13, #T_04af4_row5_col3, #T_04af4_row7_col12, #T_04af4_row12_col5, #T_04af4_row14_col4 {
#   background-color: #fedd7e;
#   color: #000000;
# }
# #T_04af4_row4_col3, #T_04af4_row5_col2, #T_04af4_row5_col9, #T_04af4_row5_col12, #T_04af4_row6_col10, #T_04af4_row7_col11 {
#   background-color: #fed06c;
#   color: #000000;
# }
# #T_04af4_row4_col5, #T_04af4_row7_col10, #T_04af4_row11_col3 {
#   background-color: #fed774;
#   color: #000000;
# }
# #T_04af4_row4_col8, #T_04af4_row10_col5 {
#   background-color: #ffe48c;
#   color: #000000;
# }
# #T_04af4_row4_col9 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_04af4_row4_col10 {
#   background-color: #fff6b6;
#   color: #000000;
# }
# #T_04af4_row4_col11 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_04af4_row4_col12, #T_04af4_row11_col9, #T_04af4_row12_col9 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_04af4_row4_col14 {
#   background-color: #fff1ab;
#   color: #000000;
# }
# #T_04af4_row5_col0, #T_04af4_row5_col1 {
#   background-color: #fb4b29;
#   color: #f1f1f1;
# }
# #T_04af4_row5_col4, #T_04af4_row7_col9, #T_04af4_row8_col9, #T_04af4_row8_col11, #T_04af4_row9_col11, #T_04af4_row9_col12 {
#   background-color: #fed470;
#   color: #000000;
# }
# #T_04af4_row5_col6, #T_04af4_row5_col7, #T_04af4_row5_col8, #T_04af4_row8_col14 {
#   background-color: #fff7b9;
#   color: #000000;
# }
# #T_04af4_row5_col11, #T_04af4_row11_col6 {
#   background-color: #fedd7f;
#   color: #000000;
# }
# #T_04af4_row5_col13 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_04af4_row5_col14, #T_04af4_row7_col14 {
#   background-color: #fff1a9;
#   color: #000000;
# }
# #T_04af4_row6_col0, #T_04af4_row6_col1, #T_04af4_row13_col4 {
#   background-color: #fd933f;
#   color: #000000;
# }
# #T_04af4_row6_col7, #T_04af4_row6_col8 {
#   background-color: #fff8bb;
#   color: #000000;
# }
# #T_04af4_row6_col9, #T_04af4_row8_col12, #T_04af4_row11_col2, #T_04af4_row12_col2 {
#   background-color: #fed36f;
#   color: #000000;
# }
# #T_04af4_row6_col12, #T_04af4_row13_col3, #T_04af4_row14_col10, #T_04af4_row14_col12 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_04af4_row6_col14 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_04af4_row7_col0, #T_04af4_row7_col1 {
#   background-color: #ce0c22;
#   color: #f1f1f1;
# }
# #T_04af4_row7_col3 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_04af4_row7_col4 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_04af4_row7_col5, #T_04af4_row7_col6, #T_04af4_row8_col5, #T_04af4_row8_col6, #T_04af4_row8_col7 {
#   background-color: #fff9be;
#   color: #000000;
# }
# #T_04af4_row8_col4 {
#   background-color: #ffe48d;
#   color: #000000;
# }
# #T_04af4_row9_col2 {
#   background-color: #febd57;
#   color: #000000;
# }
# #T_04af4_row9_col4 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_04af4_row9_col14, #T_04af4_row10_col14, #T_04af4_row12_col14 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_04af4_row10_col0, #T_04af4_row10_col1, #T_04af4_row12_col0, #T_04af4_row12_col1 {
#   background-color: #fea647;
#   color: #000000;
# }
# #T_04af4_row10_col2 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_04af4_row10_col3 {
#   background-color: #fec863;
#   color: #000000;
# }
# #T_04af4_row10_col4 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# #T_04af4_row10_col8 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_04af4_row10_col9 {
#   background-color: #fd9c42;
#   color: #000000;
# }
# #T_04af4_row11_col0, #T_04af4_row11_col1 {
#   background-color: #fea044;
#   color: #000000;
# }
# #T_04af4_row11_col5 {
#   background-color: #ffe590;
#   color: #000000;
# }
# #T_04af4_row11_col14 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_04af4_row12_col4 {
#   background-color: #fea848;
#   color: #000000;
# }
# #T_04af4_row12_col7 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_04af4_row13_col0, #T_04af4_row13_col1 {
#   background-color: #fd9740;
#   color: #000000;
# }
# #T_04af4_row13_col9 {
#   background-color: #fea948;
#   color: #000000;
# }
# #T_04af4_row13_col10, #T_04af4_row13_col11 {
#   background-color: #fffbc2;
#   color: #000000;
# }
# #T_04af4_row13_col12 {
#   background-color: #fffac1;
#   color: #000000;
# }
# #T_04af4_ro

# %%
all_train_aux
# Out:
#               V3        V4        V5        V6        V7  V1_1  V1_2  V1_3  \
# 82677   158321.0  158297.0   72476.0  106489.0  146328.0     0     0     1
# 2843    108637.0  108619.0  135179.0   75851.0   79479.0     1     0     0
# 50670    98841.0   98825.0   76316.0  137080.0  101775.0     0     1     0
# 128441    7274.0    7273.0   97161.0  128160.0  137973.0     0     0     0
# 10592   116386.0  116368.0   70382.0  140689.0  119402.0     1     0     0
# ...          ...       ...       ...       ...       ...   ...   ...   ...
# 102327   56803.0   56792.0  146134.0  114564.0   47575.0     0     0     0
# 97617    52093.0   52085.0   54989.0   81198.0   26584.0     0     0     0
# 21584   127378.0  127358.0   44795.0  105412.0   49255.0     1     0     0
# 36543    84714.0   84700.0   59207.0   33106.0  114460.0     0     1     0
# 141209   20042.0   20038.0   51811.0  160448.0   82863.0     0     0     0
#
#         V1_4  V1_5  V2_1  V2_2  V2_3  V2_4  Class
# 82677      0     0     0     0     1     0      3
# 2843       0     0     1     0     0     0     10
# 50670      0     0     0     1     0     0      4
# 128441     0     1     0     0     0     1      2
# 10592      0     0     0     1     0     0      4
# ...      ...   ...   ...   ...   ...   ...    ...
# 102327     1     0     0     1     0     0      3
# 97617      1     0     0     1     0     0     11
# 21584      0     0     1     0     0     0      3
# 36543      0     0     0     1     0     0      3
# 141209     0     1     1     0     0     0      4
#
# [82430 rows x 15 columns]

# %%
#sns.pairplot(all_train_aux, hue = 'Class', diag_kind='kde')

# %%
X_train_model = X_train_ohe
X_test_model = X_test_ohe
y_train_model = y_train
y_test_model = y_test

# %% [markdown]
# ### Borramos columnas (experimento)

# %%
#X_train_ohe = X_train_ohe.drop(columns = ['V3', 'V4', 'V1_1', 'V1_2', 'V1_3', 'V1_4', 'V1_5', 'V2_1', 'V2_2', 'V2_3', 'V2_4'])
#X_train_ohe = X_train_ohe.drop(columns = ['V3', 'V4'])

# %% [markdown]
# ## Modelado y estimación de Error out (validación cruzada)

# %%
from sklearn import linear_model
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, log_loss

# %% [markdown]
# ### Balanceo de clases (opcional)

# %%
#!pip install imblearn

# %%
#from imblearn.over_sampling import SMOTE # Library to Balance Dataset
#smote = SMOTE()
#X_train_model, y_train_model = smote.fit_resample(X_train_model, y_train) # Balancing our Data
#X_train_model, y_train_model # Checking our new shape after Over_Sampling

# %%
#from imblearn.under_sampling import RandomUnderSampler
#rus = RandomUnderSampler()
#X_train_model, y_train_model = rus.fit_resample(X_train_model, y_train)
#print('Resampled dataset shape %s' % Counter(y_train_model))
#X_train_model, y_train_model # Checking our new shape after Over_Sampling

# %% [markdown]
# ### Automatización de validación cruzada para cierto modelo

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import MinMaxScaler

# %%
def train_model(model, model_name, x_tr, y_tr, scoring):
    print(model_name)
    
    # Fitting model
    kfold = model_selection.KFold(n_splits=5)
    cv_results = model_selection.cross_validate(model, x_tr, y_tr, cv=kfold, scoring=scoring)
    #print(cv_results)
    
    for i in range(len(scoring)):
        sc = scoring[i]
        msg = "Estimation of E_out (%s): %f (%f)" % (sc, cv_results['test_' + sc].mean(), cv_results['test_' + sc].std())
        print(msg)
        print(cv_results['test_' + sc], '\n')

# %% [markdown]
# ### Regresión logística

# %%
model_lr = linear_model.LogisticRegression(penalty = 'l2', max_iter = 1000, verbose = True)
pipeline_lr = make_pipeline(MinMaxScaler(), model_lr)
model_name = 'Logistic Regression'
scoring = ['accuracy', 'neg_log_loss']
#scoring = ['accuracy']
train_model(pipeline_lr, model_name, X_train_model, y_train_model, scoring)
# Out:
# Logistic Regression
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   50.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   51.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   52.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.0min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   53.7s finished
# Estimation of E_out (accuracy): 0.392175 (0.003022)
# [0.38966396 0.39300012 0.39300012 0.38826883 0.39694286]
#
# Estimation of E_out (neg_log_loss): -1.685055 (0.006967)
# [-1.68421251 -1.69122397 -1.6783669  -1.69462993 -1.67683972]

# %%
pipeline_lr.fit(X_train_model, y_train_model)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.1min finished
# Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                 ('logisticregression',
#                  LogisticRegression(max_iter=1000, verbose=True))])

# %% [markdown]
# ### Clasificador SGD

# %%
model_sgd_lr = linear_model.SGDClassifier(loss='log', penalty='l2', max_iter=1000, tol=1e-5)
pipeline_sgd_lr = make_pipeline(MinMaxScaler(), model_sgd_lr)
model_name = 'SGD Classifier'
scoring = ['accuracy', 'neg_log_loss']
train_model(pipeline_sgd_lr, model_name, X_train_model, y_train_model, scoring)
# Out:
# SGD Classifier
# Estimation of E_out (accuracy): 0.398775 (0.002331)
# [0.39985442 0.39754944 0.40173481 0.39494116 0.39979376]
#
# Estimation of E_out (neg_log_loss): -1.688079 (0.006970)
# [-1.68514812 -1.69522676 -1.68245699 -1.6974612  -1.68010412]

# %%
pipeline_sgd_lr.fit(X_train_model, y_train_model)
# Out:
# Pipeline(steps=[('minmaxscaler', MinMaxScaler()),
#                 ('sgdclassifier', SGDClassifier(loss='log', tol=1e-05))])

# %% [markdown]
# ## Asignación 2 &#x1F921;
#
# Evalue su modelo final en el conjunto de test (X_test y y_test). Su práctica será evaluada acorde a las técnicas aplicadas, la estimación de $E_{out}$, el valor de $E_{test}$, y contra las métricas obtenidas por sus compañeros.

# %% [markdown]
# ## Cálculo de Error test

# %% [markdown]
# ### Regresión logística

# %%
# Predicting
pred_probs = pipeline_lr.predict_proba(X_test_model)
pred = pipeline_lr.predict(X_test_model)

# %%
# Scores
acc = accuracy_score(y_test_model, pred) * 100
log_losss = log_loss(y_test_model, pred_probs)
print('accuracy_score', acc, '\nlog_loss_score', log_losss)
# Out:
# accuracy_score 39.431032391119736
# log_loss_score 1.6867712832184707

# %%
# Classification Report
print('Classification Report')
print(classification_report(y_test_model, pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00      1476
#           10       0.00      0.00      0.00      9086
#           11       0.00      0.00      0.00       677
#            2       0.00      0.00      0.00      1488
#            3       0.39      0.34      0.36     16351
#            4       0.39      0.75      0.52     27312
#            5       0.00      0.00      0.00      3123
#            6       0.31      0.17      0.22      2545
#            7       0.43      0.34      0.38     13623
#            8       0.00      0.00      0.00       854
#            9       0.38      0.21      0.27      5895
#
#     accuracy                           0.39     82430
#    macro avg       0.17      0.17      0.16     82430
# weighted avg       0.31      0.39      0.33     82430

# %% [markdown]
# ### Clasificador SGD

# %%
# Predicting
pred_probs = pipeline_sgd_lr.predict_proba(X_test_model)
pred = pipeline_sgd_lr.predict(X_test_model)

# %%
# Scores
acc = accuracy_score(y_test_model, pred) * 100
log_losss = log_loss(y_test_model, pred_probs)
print('accuracy_score', acc, '\nlog_loss_score', log_losss)
# Out:
# accuracy_score 40.16620162562174
# log_loss_score 1.690193077888487

# %%
# Classification Report
print('Classification Report')
print(classification_report(y_test_model, pred))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00      1476
#           10       0.00      0.00      0.00      9086
#           11       0.00      0.00      0.00       677
#            2       0.00      0.00      0.00      1488
#            3       0.43      0.29      0.35     16351
#            4       0.39      0.82      0.53     27312
#            5       0.00      0.00      0.00      3123
#            6       0.29      0.09      0.14      2545
#            7       0.42      0.36      0.39     13623
#            8       0.00      0.00      0.00       854
#            9       0.48      0.16      0.24      5895
#
#     accuracy                           0.40     82430
#    macro avg       0.18      0.16      0.15     82430
# weighted avg       0.33      0.40      0.33     82430

# %%
#sklearn.metrics.SCORERS.keys()

# %%
#sklearn.metrics.log_loss
